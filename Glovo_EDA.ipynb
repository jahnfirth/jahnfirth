# %%
pip install emoji
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import emoji

# %% [markdown]
# # Glovo - Take Home Assignment
#
# ## Data Analyst :chart_with_upwards_trend: - Acquisition (They/She/He)
#
# ### Applicant: Jahn Firth Ph.D.
#
# > :e-mail: jahnfirth@gmail.com :iphone: +34646909469 :computer: https://www.jahnfirth.com/
#
# ---
# ___
#
# This notebook contains python code to answer questions related to Exercise 3 of the Take Home Assignment.
#
# For exercise 1 & 2 please see:
# - README
# -
# -
#
# Make a content table 'links'
#
# > This notebook **contains**
# > a special analysis
# > of Glovo
#
# - [x] Exercise 1
# - [x] Exercise 2
# - [x] Exercise 3

# %% [markdown]
# ## Imported libraries for data wrangling, analysis and visualisation

# %%
import pandas as pd
import numpy as np

#Display max rows to 100 (inspect more rows per output)
pd.set_option('display.max_rows', 100)

# %% [markdown]
# Week of analysis

# %% [markdown]
# ## Read .csv files into dataframes

# %%
vertical = pd.read_csv('data_vertical.csv')
vertical.head(10)
# Out:
#    partner_id vertical
# 0      169385     Food
# 1      230660     Food
# 2      247635     Food
# 3      341110     Food
# 4      368335     Food
# 5      472910     Food
# 6      509785     Food
# 7      584785     Food
# 8      883360     Food
# 9      884885     Food

# %%
business_seg = pd.read_csv('data_business_segments.csv')
business_seg.head(10)
# Out:
#    partner_id business_segment
# 0      169385       Local Hero
# 1      230660        Long Tail
# 2      247635            Chain
# 3      341110            Chain
# 4      368335        Long Tail
# 5      472910        Long Tail
# 6      509785       Local Hero
# 7      584785       Local Hero
# 8      883360            Chain
# 9      884885       Local Hero

# %%
integrations = pd.read_csv('data_integrations.csv')
integrations.head(10)
# Out:
#    partner_id  is_integrated
# 0      169385          False
# 1      230660          False
# 2      247635           True
# 3      341110          False
# 4      368335          False
# 5      472910          False
# 6      509785          False
# 7      584785          False
# 8      883360          False
# 9      884885           True

# %%
countries = pd.read_csv('data_countries.csv')
countries.head(10)
# Out:
#    partner_id country
# 0      169385      ES
# 1      230660      PT
# 2      247635      ES
# 3      341110      ES
# 4      368335      ES
# 5      472910      ES
# 6      509785      PT
# 7      584785      IT
# 8      883360      IT
# 9      884885      ES

# %%
finance = pd.read_csv('data_finance.csv')
finance.head(10)
# Out:
#          date  partner_id  avg_order_cost  avg_order_revenue
# 0  2021-08-12      169385        4.663740          11.442900
# 1  2021-08-12      230660        5.677032           9.390732
# 2  2021-08-12      247635       19.922868          26.112144
# 3  2021-08-12      341110       18.669470          26.663880
# 4  2021-08-12      368335       17.023120          13.384300
# 5  2021-08-12      472910        9.181950          27.454200
# 6  2021-08-12      509785        8.157070          24.768290
# 7  2021-08-12      584785       10.024500          25.200000
# 8  2021-08-12      883360       11.899270          24.331470
# 9  2021-08-12      884885        9.485556          15.293556

# %%
operations = pd.read_csv('data_operations.csv')
operations.head(10)
# Out:
#          date  partner_id  avg_delivery_time_min  avg_preparation_time_min
# 0  2021-08-12      169385              18.216667                  5.520000
# 1  2021-08-12      230660              36.888333                 13.168571
# 2  2021-08-12      247635              41.230000                 22.892000
# 3  2021-08-12      341110              38.644444                 17.560000
# 4  2021-08-12      368335              33.683333                  5.566667
# 5  2021-08-12      472910              29.750000                 12.150000
# 6  2021-08-12      509785              39.577778                 30.670000
# 7  2021-08-12      584785              22.266667                 12.780000
# 8  2021-08-12      883360              49.727778                 11.220000
# 9  2021-08-12      884885              21.910000                  9.336000

# %%
orders = pd.read_csv('data_orders.csv')
orders.head(10)
# Out:
#          date  partner_id  orders_daily  connected_hours
# 0  2021-08-12      169385           1.0                7
# 1  2021-08-12      230660          10.0                0
# 2  2021-08-12      247635           5.0                0
# 3  2021-08-12      341110           3.0                6
# 4  2021-08-12      368335           3.0                0
# 5  2021-08-12      472910           1.0                5
# 6  2021-08-12      509785           3.0                6
# 7  2021-08-12      584785           1.0                5
# 8  2021-08-12      883360           3.0                8
# 9  2021-08-12      884885           5.0                0

# %% [markdown]
# ### Observations
#
# Four csv came from
# - data_vertical as **vertical**
# - data_business_segments as **business_seg**
# - data_integrations as **integrations**
# - data_countries as **countries**
#
# Three csv came from
# -
# -
# -

# %% [markdown]
# # Exploratory data analysis
#
# ### Prior to data wrangling (joining tables)
#
# #### Purpose
# - Understand data
# -
# -
#
# #### Objectives
# -
# -
# - lead onto Exercise 3

# %%
business_seg['business_segment'].value_counts()
# Out:
# Long Tail     21273
# Chain          7529
# Q-Commerce     7110
# Local Hero     5475
# Big Chain      3730
# Sidekick       1089
# Name: business_segment, dtype: int64

# %%
countries['country'].value_counts()
# Out:
# ES    22183
# IT    10840
# UA     6808
# PT     6377
# Name: country, dtype: int64

# %%
integrations['is_integrated'].value_counts()
# Out:
# False    35232
# True     10976
# Name: is_integrated, dtype: int64

# %%
orders['orders_daily'].head(100)
# Out:
# 0       1.0
# 1      10.0
# 2       5.0
# 3       3.0
# 4       3.0
# 5       1.0
# 6       3.0
# 7       1.0
# 8       3.0
# 9       5.0
# 10      3.0
# 11      9.0
# 12      3.0
# 13      2.0
# 14      1.0
# 15    332.0
# 16      4.0
# 17     12.0
# 18      1.0
# 19     30.0
# 20      5.0
# 21      4.0
# 22      6.0
# 23      1.0
# 24      4.0
# 25      1.0
# 26      3.0
# 27      2.0
# 28      6.0
# 29      1.0
# 30     46.0
# 31      2.0
# 32      3.0
# 33      1.0
# 34      1.0
# 35      6.0
# 36      1.0
# 37      5.0
# 38      9.0
# 39     18.0
# 40      6.0
# 41      1.0
# 42      1.0
# 43      1.0
# 44      2.0
# 45      1.0
# 46      5.0
# 47      4.0
# 48      1.0
# 49      3.0
# 50      1.0
# 51      1.0
# 52     23.0
# 53      5.0
# 54      1.0
# 55      2.0
# 56      1.0
# 57      1.0
# 58      1.0
# 59     20.0
# 60      1.0
# 61      1.0
# 62      2.0
# 63      3.0
# 64      9.0
# 65      1.0
# 66      3.0
# 67      4.0
# 68     11.0
# 69      4.0
# 70      1.0
# ...

# %%
orders['partner_id'].value_counts()
# Out:
# 7074110    7
# 2576035    7
# 7184685    7
# 204585     7
# 4014385    7
#           ..
# 2497885    1
# 6802335    1
# 4696185    1
# 640660     1
# 4543510    1
# Name: partner_id, Length: 46208, dtype: int64

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190708 entries, 0 to 190707
# Data columns (total 4 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   date             190708 non-null  object
#  1   partner_id       190708 non-null  int64
#  2   orders_daily     190708 non-null  float64
#  3   connected_hours  190708 non-null  int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 5.8+ MB

# %%
orders['date'] = pd.to_datetime(orders['date'])
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190708 entries, 0 to 190707
# Data columns (total 4 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   date             190708 non-null  datetime64[ns]
#  1   partner_id       190708 non-null  int64
#  2   orders_daily     190708 non-null  float64
#  3   connected_hours  190708 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(2)
# memory usage: 5.8 MB

# %%
vertical['vertical'].value_counts()
# Out:
# Food          39098
# Q-commerce     7110
# Name: vertical, dtype: int64

# %%
from functools import reduce

# %%
data_frames = [vertical, business_seg, integrations, countries]

# %%
df_merged = reduce(lambda left,right: pd.merge(left,right,on=['partner_id'], how='outer'), data_frames)
df_merged
# Out:
#        partner_id    vertical business_segment  is_integrated country
# 0          169385        Food       Local Hero          False      ES
# 1          230660        Food        Long Tail          False      PT
# 2          247635        Food            Chain           True      ES
# 3          341110        Food            Chain          False      ES
# 4          368335        Food        Long Tail          False      ES
# ...           ...         ...              ...            ...     ...
# 46203     5266435  Q-commerce       Q-Commerce           True      UA
# 46204     5665210        Food       Local Hero          False      ES
# 46205     6446560        Food        Long Tail          False      ES
# 46206     6512635        Food        Long Tail          False      ES
# 46207     7269060  Q-commerce       Q-Commerce           True      UA
#
# [46208 rows x 5 columns]

# %%
df = df_merged

# %%
df
# Out:
#        partner_id    vertical business_segment  is_integrated country
# 0          169385        Food       Local Hero          False      ES
# 1          230660        Food        Long Tail          False      PT
# 2          247635        Food            Chain           True      ES
# 3          341110        Food            Chain          False      ES
# 4          368335        Food        Long Tail          False      ES
# ...           ...         ...              ...            ...     ...
# 46203     5266435  Q-commerce       Q-Commerce           True      UA
# 46204     5665210        Food       Local Hero          False      ES
# 46205     6446560        Food        Long Tail          False      ES
# 46206     6512635        Food        Long Tail          False      ES
# 46207     7269060  Q-commerce       Q-Commerce           True      UA
#
# [46208 rows x 5 columns]

# %%
df['partner_id'].value_counts().loc[lambda x : x==1]
# Out:
# 6621185    1
# 7350960    1
# 7942835    1
# 6691510    1
# 6645585    1
#           ..
# 8099160    1
# 7711685    1
# 4492635    1
# 5748060    1
# 5441535    1
# Name: partner_id, Length: 46208, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46208 entries, 0 to 46207
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   partner_id        46208 non-null  int64
#  1   vertical          46208 non-null  object
#  2   business_segment  46206 non-null  object
#  3   is_integrated     46208 non-null  bool
#  4   country           46208 non-null  object
# dtypes: bool(1), int64(1), object(3)
# memory usage: 1.8+ MB

# %%
df.isnull().sum()
# Out:
# partner_id          0
# vertical            0
# business_segment    2
# is_integrated       0
# country             0
# dtype: int64

# %%
df.isna().any()
# Out:
# partner_id          False
# vertical            False
# business_segment     True
# is_integrated       False
# country             False
# dtype: bool

# %%
rows_with_nan = [index for index, row in df.iterrows() if row.isnull().any()]

print(rows_with_nan)
# Out:
# [39568, 41169]

# %%
df.iloc[[39568, 41169]]
# Out:
#        partner_id vertical business_segment  is_integrated country
# 39568     8682335     Food              NaN          False      PT
# 41169     8698685     Food              NaN          False      PT

# %% [markdown]
# ### Data quaility assumptions
#
# Two missing data points were identified in the business_segement
# General assumptions - while the remaining do not contain missing values, the general assumption is that the data are correct, high quaility,
#
# data values are accurate, reliable, consistent.
# sampling randomly can faciliate the above query

# %%
#preference to randomly sample the data rather than use .head() or .tail()

df.sample(40)
# Out:
#        partner_id    vertical business_segment  is_integrated country
# 43484     5992935        Food        Big Chain           True      IT
# 31705     7118260        Food        Long Tail          False      ES
# 1956      5501360        Food       Local Hero          False      ES
# 31791     4529235        Food        Long Tail          False      ES
# 15452     6453660  Q-commerce       Q-Commerce           True      ES
# 39671     5455785        Food            Chain           True      ES
# 15643     7097785        Food         Sidekick          False      UA
# 41195     5751660        Food            Chain          False      ES
# 30695     7886110        Food        Long Tail          False      IT
# 7956      7885385        Food        Long Tail          False      UA
# 12942     4428485        Food            Chain          False      PT
# 25449     5891385        Food        Long Tail          False      ES
# ...

# %% [markdown]
# ## Observation:
#
# Dataset appears to be structured
# There is a slight inconsistency between the capitalization of the **C** (Q-commerce / Q-Commerce) between `df['vertical']` and `df['business_segment']`
#
# ### Suggested approach
#
# Use string replace method to target the c in Q-commerce
#
# business_segment_clean = df['business_segment'].str.replace("Q-C", "Q-c")
# or
# vertical_clean = df['vertical'].str.replace("Q-c", "Q-C")

# %% [markdown]
# ## Daily matrics tables
#
# orders operations finance

# %%
orders.head()
# Out:
#         date  partner_id  orders_daily  connected_hours
# 0 2021-08-12      169385           1.0                7
# 1 2021-08-12      230660          10.0                0
# 2 2021-08-12      247635           5.0                0
# 3 2021-08-12      341110           3.0                6
# 4 2021-08-12      368335           3.0                0

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190708 entries, 0 to 190707
# Data columns (total 4 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   date             190708 non-null  datetime64[ns]
#  1   partner_id       190708 non-null  int64
#  2   orders_daily     190708 non-null  float64
#  3   connected_hours  190708 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(2)
# memory usage: 5.8 MB

# %%
operations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190708 entries, 0 to 190707
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   date                      190708 non-null  object
#  1   partner_id                190708 non-null  int64
#  2   avg_delivery_time_min     190708 non-null  float64
#  3   avg_preparation_time_min  190708 non-null  float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 5.8+ MB

# %%
operations['date'] = pd.to_datetime(operations['date'])
finance['date'] = pd.to_datetime(finance['date'])

# %%
operations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190708 entries, 0 to 190707
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   date                      190708 non-null  datetime64[ns]
#  1   partner_id                190708 non-null  int64
#  2   avg_delivery_time_min     190708 non-null  float64
#  3   avg_preparation_time_min  190708 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1)
# memory usage: 5.8 MB

# %%
finance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190708 entries, 0 to 190707
# Data columns (total 4 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   date               190708 non-null  datetime64[ns]
#  1   partner_id         190708 non-null  int64
#  2   avg_order_cost     190708 non-null  float64
#  3   avg_order_revenue  190708 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1)
# memory usage: 5.8 MB

# %%
data_frames_metric = [orders, operations, finance]
df_merged_metric = reduce(lambda left,right: pd.merge(left,right,how='inner', left_index=True, right_index=True), data_frames_metric)
df_merged_metric.head(10)
# Out:
#       date_x  partner_id_x  orders_daily  connected_hours     date_y  \
# 0 2021-08-12        169385           1.0                7 2021-08-12
# 1 2021-08-12        230660          10.0                0 2021-08-12
# 2 2021-08-12        247635           5.0                0 2021-08-12
# 3 2021-08-12        341110           3.0                6 2021-08-12
# 4 2021-08-12        368335           3.0                0 2021-08-12
# 5 2021-08-12        472910           1.0                5 2021-08-12
# 6 2021-08-12        509785           3.0                6 2021-08-12
# 7 2021-08-12        584785           1.0                5 2021-08-12
# 8 2021-08-12        883360           3.0                8 2021-08-12
# 9 2021-08-12        884885           5.0                0 2021-08-12
#
#    partner_id_y  avg_delivery_time_min  avg_preparation_time_min       date  \
# 0        169385              18.216667                  5.520000 2021-08-12
# ...

# %%
df_merged_metric.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190708 entries, 0 to 190707
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   date_x                    190708 non-null  datetime64[ns]
#  1   partner_id_x              190708 non-null  int64
#  2   orders_daily              190708 non-null  float64
#  3   connected_hours           190708 non-null  int64
#  4   date_y                    190708 non-null  datetime64[ns]
#  5   partner_id_y              190708 non-null  int64
#  6   avg_delivery_time_min     190708 non-null  float64
#  7   avg_preparation_time_min  190708 non-null  float64
#  8   date                      190708 non-null  datetime64[ns]
#  9   partner_id                190708 non-null  int64
#  10  avg_order_cost            190708 non-null  float64
#  11  avg_order_revenue         190708 non-null  float64
# dtypes: datetime64[ns](3), float64(5), int64(4)
# ...

# %% [markdown]
# ### Reordered/dropped columns from metrics dataframe
#
# Assigned new dataframe (**df_metrics**) to exclude duplicated columns 'date' and 'partner_id'

# %%
df_metrics = df_merged_metric[['date', 'partner_id', 'orders_daily', 'connected_hours', 
       'avg_delivery_time_min', 'avg_preparation_time_min', 'avg_order_cost', 'avg_order_revenue']]
df_metrics.head()
# Out:
#         date  partner_id  orders_daily  connected_hours  \
# 0 2021-08-12      169385           1.0                7
# 1 2021-08-12      230660          10.0                0
# 2 2021-08-12      247635           5.0                0
# 3 2021-08-12      341110           3.0                6
# 4 2021-08-12      368335           3.0                0
#
#    avg_delivery_time_min  avg_preparation_time_min  avg_order_cost  \
# 0              18.216667                  5.520000        4.663740
# 1              36.888333                 13.168571        5.677032
# 2              41.230000                 22.892000       19.922868
# 3              38.644444                 17.560000       18.669470
# 4              33.683333                  5.566667       17.023120
#
#    avg_order_revenue
# 0          11.442900
# 1           9.390732
# 2          26.112144
# 3          26.663880
# 4          13.384300

# %%
df_metrics.loc[df_metrics['partner_id'] == 169385]
# Out:
#             date  partner_id  orders_daily  connected_hours  \
# 0     2021-08-12      169385           1.0                7
# 14589 2021-08-18      169385           1.0               11
#
#        avg_delivery_time_min  avg_preparation_time_min  avg_order_cost  \
# 0                  18.216667                      5.52         4.66374
# 14589              25.650000                     20.67         7.30719
#
#        avg_order_revenue
# 0               11.44290
# 14589           14.86389

# %%
orders.loc[orders['partner_id'] == 169385]
# Out:
#             date  partner_id  orders_daily  connected_hours
# 0     2021-08-12      169385           1.0                7
# 14589 2021-08-18      169385           1.0               11

# %%
df_metrics.loc[df_metrics['partner_id'] == 230660]
# Out:
#             date  partner_id  orders_daily  connected_hours  \
# 1     2021-08-12      230660          10.0                0
# 134   2021-08-13      230660          11.0                0
# 979   2021-08-14      230660          12.0                0
# 1911  2021-08-15      230660          10.0                0
# 2997  2021-08-16      230660           1.0                0
# 4335  2021-08-17      230660           3.0                2
# 14590 2021-08-18      230660           2.0                2
#
#        avg_delivery_time_min  avg_preparation_time_min  avg_order_cost  \
# 1                  36.888333                 13.168571        5.677032
# 134                24.719697                  6.742727        7.629251
# 979                23.791667                  9.117143        7.785342
# 1911               26.930000                  9.055833        8.080998
# 2997               18.666667                  8.000000        5.994720
# ...

# %% [markdown]
# ### Date range 2021-08-12 - 2021-08-18

# %%
df_metrics['date'].value_counts().sort_index()
# Out:
# 2021-08-12    27881
# 2021-08-13    28920
# 2021-08-14    28726
# 2021-08-15    26985
# 2021-08-16    25412
# 2021-08-17    26072
# 2021-08-18    26712
# Name: date, dtype: int64

# %%
df_metrics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190708 entries, 0 to 190707
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   date                      190708 non-null  datetime64[ns]
#  1   partner_id                190708 non-null  int64
#  2   orders_daily              190708 non-null  float64
#  3   connected_hours           190708 non-null  int64
#  4   avg_delivery_time_min     190708 non-null  float64
#  5   avg_preparation_time_min  190708 non-null  float64
#  6   avg_order_cost            190708 non-null  float64
#  7   avg_order_revenue         190708 non-null  float64
# dtypes: datetime64[ns](1), float64(5), int64(2)
# memory usage: 11.6 MB

# %%
df_metrics.shape
# Out:
# (190708, 8)

# %%
orders.shape
# Out:
# (190708, 4)

# %%
orders.loc[orders['partner_id'] == 169385]
# Out:
#             date  partner_id  orders_daily  connected_hours
# 0     2021-08-12      169385           1.0                7
# 14589 2021-08-18      169385           1.0               11
